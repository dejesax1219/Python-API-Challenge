# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# gel
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | rio gallegos
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | hermanus
# Processing Record 21 of Set 4 | gadsden
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | mangrol
# Processing Record 24 of Set 4 | el carmen
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | aykhal
# Processing Record 27 of Set 4 | prabumulih
# Processing Record 28 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | sayyan
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | lozuvatka
# Processing Record 33 of Set 4 | kaitangata
# Processing Record 34 of Set 4 | la ronge
# Processing Record 35 of Set 4 | kurayoshi
# Processing Record 36 of Set 4 | slave lake
# Processing Record 37 of Set 4 | rodionovo-nesvetayskaya
# Processing Record 38 of Set 4 | hauterive
# Processing Record 39 of Set 4 | kunming
# Processing Record 40 of Set 4 | olkhovka
# Processing Record 41 of Set 4 | santo antonio do ica
# Processing Record 42 of Set 4 | le port
# Processing Record 43 of Set 4 | bredasdorp
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | puerto ayora
# Processing Record 46 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 4 | kansanshi
# Processing Record 48 of Set 4 | roald
# Processing Record 49 of Set 4 | evensk
# Processing Record 0 of Set 5 | srednekolymsk
# Processing Record 1 of Set 5 | shiyan
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | kindersley
# Processing Record 4 of Set 5 | kurumkan
# Processing Record 5 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 5 | kloulklubed
# Processing Record 7 of Set 5 | lingao
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | carrizal
# Processing Record 10 of Set 5 | sena madureira
# Processing Record 11 of Set 5 | kholmy
# Processing Record 12 of Set 5 | jaru
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | pemangkat
# Processing Record 15 of Set 5 | peniche
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 5 | svetlaya
# Processing Record 19 of Set 5 | vilhena
# Processing Record 20 of Set 5 | amazar
# Processing Record 21 of Set 5 | det udom
# Processing Record 22 of Set 5 | vardo
# Processing Record 23 of Set 5 | jamestown
# Processing Record 24 of Set 5 | conde
# Processing Record 25 of Set 5 | fort nelson
# Processing Record 26 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 5 | batagay
# Processing Record 28 of Set 5 | thunder bay
# Processing Record 29 of Set 5 | chapais
# Processing Record 30 of Set 5 | hasaki
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | kuytun
# Processing Record 33 of Set 5 | akmene
# Processing Record 34 of Set 5 | sambava
# Processing Record 35 of Set 5 | muros
# Processing Record 36 of Set 5 | linxia
# Processing Record 37 of Set 5 | zhigansk
# Processing Record 38 of Set 5 | luanda
# Processing Record 39 of Set 5 | bambanglipuro
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 5 | missungwi
# Processing Record 43 of Set 5 | pingdingshan
# Processing Record 44 of Set 5 | clarence town
# Processing Record 45 of Set 5 | russell
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | camana
# Processing Record 48 of Set 5 | hualmay
# Processing Record 49 of Set 5 | lekoni
# Processing Record 0 of Set 6 | nome
# Processing Record 1 of Set 6 | ye
# City not found. Skipping...
# Processing Record 2 of Set 6 | mattawa
# Processing Record 3 of Set 6 | geraldton
# Processing Record 4 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 6 | olavarria
# Processing Record 6 of Set 6 | haapiti
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | verkhnyaya inta
# Processing Record 10 of Set 6 | basoko
# Processing Record 11 of Set 6 | dinghai
# Processing Record 12 of Set 6 | najran
# Processing Record 13 of Set 6 | dahra
# Processing Record 14 of Set 6 | kpandu
# Processing Record 15 of Set 6 | lamu
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | parrita
# Processing Record 18 of Set 6 | mednogorsk
# Processing Record 19 of Set 6 | mount isa
# Processing Record 20 of Set 6 | bonnyville
# Processing Record 21 of Set 6 | havre-saint-pierre
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | aloleng
# Processing Record 24 of Set 6 | santiago
# Processing Record 25 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 26 of Set 6 | faya
# Processing Record 27 of Set 6 | victoria
# Processing Record 28 of Set 6 | klaksvik
# Processing Record 29 of Set 6 | hobyo
# Processing Record 30 of Set 6 | bara
# Processing Record 31 of Set 6 | muyezerskiy
# Processing Record 32 of Set 6 | bajil
# Processing Record 33 of Set 6 | montego bay
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | odweyne
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | dudinka
# Processing Record 38 of Set 6 | portobelo
# Processing Record 39 of Set 6 | bereda
# Processing Record 40 of Set 6 | luxor
# Processing Record 41 of Set 6 | fare
# Processing Record 42 of Set 6 | tarata
# Processing Record 43 of Set 6 | bowen
# Processing Record 44 of Set 6 | vila do maio
# Processing Record 45 of Set 6 | aasiaat
# Processing Record 46 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 6 | kieta
# Processing Record 48 of Set 6 | marsa matruh
# Processing Record 49 of Set 6 | longkou
# Processing Record 0 of Set 7 | ierapetra
# Processing Record 1 of Set 7 | nabire
# Processing Record 2 of Set 7 | humaita
# Processing Record 3 of Set 7 | foam lake
# Processing Record 4 of Set 7 | carutapera
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | itaituba
# Processing Record 7 of Set 7 | lavrentiya
# Processing Record 8 of Set 7 | sharan
# Processing Record 9 of Set 7 | danielskuil
# Processing Record 10 of Set 7 | soe
# Processing Record 11 of Set 7 | ovalle
# Processing Record 12 of Set 7 | asosa
# Processing Record 13 of Set 7 | benguela
# Processing Record 14 of Set 7 | iquitos
# Processing Record 15 of Set 7 | gornyy
# Processing Record 16 of Set 7 | businga
# Processing Record 17 of Set 7 | adrar
# Processing Record 18 of Set 7 | huangnihe
# Processing Record 19 of Set 7 | itarema
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | awjilah
# Processing Record 23 of Set 7 | bud
# Processing Record 24 of Set 7 | ramotswa
# Processing Record 25 of Set 7 | pisco
# Processing Record 26 of Set 7 | dhamtari
# Processing Record 27 of Set 7 | talara
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | ziyang
# Processing Record 30 of Set 7 | loa janan
# Processing Record 31 of Set 7 | castro
# Processing Record 32 of Set 7 | nahariyya
# Processing Record 33 of Set 7 | filingue
# Processing Record 34 of Set 7 | nioro
# Processing Record 35 of Set 7 | navirai
# Processing Record 36 of Set 7 | usinsk
# Processing Record 37 of Set 7 | hami
# Processing Record 38 of Set 7 | zyryanka
# Processing Record 39 of Set 7 | hambantota
# Processing Record 40 of Set 7 | kalianget
# Processing Record 41 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | kushmurun
# Processing Record 45 of Set 7 | tiarei
# Processing Record 46 of Set 7 | tuatapere
# Processing Record 47 of Set 7 | opuwo
# Processing Record 48 of Set 7 | yellowknife
# Processing Record 49 of Set 7 | peterhead
# Processing Record 0 of Set 8 | ola
# Processing Record 1 of Set 8 | okato
# Processing Record 2 of Set 8 | zverinogolovskoye
# Processing Record 3 of Set 8 | punta de piedra
# Processing Record 4 of Set 8 | grand-lahou
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | schubelbach
# Processing Record 7 of Set 8 | talnakh
# Processing Record 8 of Set 8 | borba
# Processing Record 9 of Set 8 | puerto leguizamo
# Processing Record 10 of Set 8 | kingsville
# Processing Record 11 of Set 8 | taoudenni
# Processing Record 12 of Set 8 | bubaque
# Processing Record 13 of Set 8 | acajutla
# Processing Record 14 of Set 8 | cuiluan
# Processing Record 15 of Set 8 | batagay-alyta
# Processing Record 16 of Set 8 | kamaishi
# Processing Record 17 of Set 8 | cape coast
# Processing Record 18 of Set 8 | nikki
# Processing Record 19 of Set 8 | shafranovo
# Processing Record 20 of Set 8 | poshtove
# Processing Record 21 of Set 8 | mabaruma
# Processing Record 22 of Set 8 | portland
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | panama city
# Processing Record 25 of Set 8 | zhicheng
# Processing Record 26 of Set 8 | ahuimanu
# Processing Record 27 of Set 8 | port macquarie
# Processing Record 28 of Set 8 | galesong
# Processing Record 29 of Set 8 | forbes
# Processing Record 30 of Set 8 | labuan
# Processing Record 31 of Set 8 | parakan
# Processing Record 32 of Set 8 | tecoanapa
# Processing Record 33 of Set 8 | cidreira
# Processing Record 34 of Set 8 | preveza
# Processing Record 35 of Set 8 | the valley
# Processing Record 36 of Set 8 | ancud
# Processing Record 37 of Set 8 | caloundra
# Processing Record 38 of Set 8 | cotonou
# Processing Record 39 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 8 | port hedland
# Processing Record 41 of Set 8 | athens
# Processing Record 42 of Set 8 | reshetylivka
# Processing Record 43 of Set 8 | bueu
# Processing Record 44 of Set 8 | pala
# Processing Record 45 of Set 8 | dracena
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | tual
# Processing Record 49 of Set 8 | diplo
# Processing Record 0 of Set 9 | sitka
# Processing Record 1 of Set 9 | teahupoo
# Processing Record 2 of Set 9 | el fuerte
# Processing Record 3 of Set 9 | voh
# Processing Record 4 of Set 9 | rio claro
# Processing Record 5 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 9 | coahuayana
# Processing Record 7 of Set 9 | tzucacab
# Processing Record 8 of Set 9 | payo
# Processing Record 9 of Set 9 | norwich
# Processing Record 10 of Set 9 | paramonga
# Processing Record 11 of Set 9 | inhambane
# Processing Record 12 of Set 9 | sur
# Processing Record 13 of Set 9 | bhanjanagar
# Processing Record 14 of Set 9 | visby
# Processing Record 15 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 9 | ulaanbaatar
# Processing Record 17 of Set 9 | cherskiy
# Processing Record 18 of Set 9 | lososina
# Processing Record 19 of Set 9 | vostok
# Processing Record 20 of Set 9 | kizilskoye
# Processing Record 21 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 9 | hailey
# Processing Record 23 of Set 9 | templin
# Processing Record 24 of Set 9 | derby
# Processing Record 25 of Set 9 | mitu
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | koboldo
# City not found. Skipping...
# Processing Record 28 of Set 9 | dingle
# Processing Record 29 of Set 9 | coffs harbour
# Processing Record 30 of Set 9 | valdemarpils
# Processing Record 31 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 32 of Set 9 | berezovyy
# Processing Record 33 of Set 9 | palu
# Processing Record 34 of Set 9 | shakawe
# Processing Record 35 of Set 9 | usevya
# Processing Record 36 of Set 9 | vagur
# Processing Record 37 of Set 9 | tripoli
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | les cayes
# Processing Record 40 of Set 9 | goderich
# Processing Record 41 of Set 9 | valreas
# Processing Record 42 of Set 9 | sydney
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | kristiansund
# Processing Record 45 of Set 9 | ushtobe
# Processing Record 46 of Set 9 | salalah
# Processing Record 47 of Set 9 | ponta delgada
# Processing Record 48 of Set 9 | nacala
# Processing Record 49 of Set 9 | qaqortoq
# Processing Record 0 of Set 10 | beringovskiy
# Processing Record 1 of Set 10 | marataizes
# Processing Record 2 of Set 10 | bronnoysund
# Processing Record 3 of Set 10 | turbat
# Processing Record 4 of Set 10 | muromtsevo
# Processing Record 5 of Set 10 | imbituba
# Processing Record 6 of Set 10 | suar
# Processing Record 7 of Set 10 | san quintin
# Processing Record 8 of Set 10 | lisburn
# Processing Record 9 of Set 10 | biak
# Processing Record 10 of Set 10 | anadyr
# Processing Record 11 of Set 10 | krasnyy oktyabr
# Processing Record 12 of Set 10 | lubawa
# Processing Record 13 of Set 10 | lazaro cardenas
# Processing Record 14 of Set 10 | henties bay
# Processing Record 15 of Set 10 | clifton
# Processing Record 16 of Set 10 | bucerias
# Processing Record 17 of Set 10 | karlstad
# Processing Record 18 of Set 10 | maihar
# Processing Record 19 of Set 10 | iquique
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | san pedro
# Processing Record 23 of Set 10 | airai
# Processing Record 24 of Set 10 | zaria
# Processing Record 25 of Set 10 | ambulu
# Processing Record 26 of Set 10 | norman wells
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | mitsamiouli
# Processing Record 30 of Set 10 | upata
# Processing Record 31 of Set 10 | husavik
# Processing Record 32 of Set 10 | asyut
# Processing Record 33 of Set 10 | mwinilunga
# Processing Record 34 of Set 10 | acari
# Processing Record 35 of Set 10 | lumberton
# Processing Record 36 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 38 of Set 10 | barentu
# Processing Record 39 of Set 10 | tongliao
# Processing Record 40 of Set 10 | chara
# Processing Record 41 of Set 10 | qibili
# City not found. Skipping...
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | mayor pablo lagerenza
# Processing Record 44 of Set 10 | akdepe
# Processing Record 45 of Set 10 | ostrovnoy
# Processing Record 46 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 47 of Set 10 | pahrump
# Processing Record 48 of Set 10 | alofi
# Processing Record 49 of Set 10 | comodoro rivadavia
# Processing Record 0 of Set 11 | shumskiy
# Processing Record 1 of Set 11 | telimele
# Processing Record 2 of Set 11 | dunedin
# Processing Record 3 of Set 11 | valparaiso
# Processing Record 4 of Set 11 | cocorit
# Processing Record 5 of Set 11 | paita
# Processing Record 6 of Set 11 | kabare
# Processing Record 7 of Set 11 | alunitdag
# City not found. Skipping...
# Processing Record 8 of Set 11 | griffith
# Processing Record 9 of Set 11 | ludza
# Processing Record 10 of Set 11 | karuzi
# Processing Record 11 of Set 11 | polyarnyy
# Processing Record 12 of Set 11 | tawau
# Processing Record 13 of Set 11 | greenwood
# Processing Record 14 of Set 11 | princeton
# Processing Record 15 of Set 11 | ballina
# Processing Record 16 of Set 11 | isahaya
# Processing Record 17 of Set 11 | mayumba
# Processing Record 18 of Set 11 | cascais
# Processing Record 19 of Set 11 | camapua
# Processing Record 20 of Set 11 | bontang
# Processing Record 21 of Set 11 | tommot
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | san vicente
# Processing Record 24 of Set 11 | vendome
# Processing Record 25 of Set 11 | entre rios
# Processing Record 26 of Set 11 | abonnema
# Processing Record 27 of Set 11 | ambalavao
# Processing Record 28 of Set 11 | burgeo
# Processing Record 29 of Set 11 | lata
# Processing Record 30 of Set 11 | yuli
# Processing Record 31 of Set 11 | beni suef
# Processing Record 32 of Set 11 | guanica
# Processing Record 33 of Set 11 | yako
# Processing Record 34 of Set 11 | laishevo
# Processing Record 35 of Set 11 | mareeba
# Processing Record 36 of Set 11 | alta floresta
# Processing Record 37 of Set 11 | carauari
# Processing Record 38 of Set 11 | sturgeon bay
# Processing Record 39 of Set 11 | berdigestyakh
# Processing Record 40 of Set 11 | athabasca
# Processing Record 41 of Set 11 | homa bay
# Processing Record 42 of Set 11 | constitucion
# Processing Record 43 of Set 11 | kedougou
# Processing Record 44 of Set 11 | zhigalovo
# Processing Record 45 of Set 11 | salvador
# Processing Record 46 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 11 | binabalian
# Processing Record 48 of Set 11 | necochea
# Processing Record 49 of Set 11 | ilulissat
# Processing Record 0 of Set 12 | bemidji
# Processing Record 1 of Set 12 | comal
# Processing Record 2 of Set 12 | catuday
# Processing Record 3 of Set 12 | lingig
# Processing Record 4 of Set 12 | araouane
# Processing Record 5 of Set 12 | los llanos de aridane
# Processing Record 6 of Set 12 | hoopstad
# Processing Record 7 of Set 12 | salinas
# Processing Record 8 of Set 12 | gollere
# City not found. Skipping...
# Processing Record 9 of Set 12 | tazovskiy
# Processing Record 10 of Set 12 | toucheng
# Processing Record 11 of Set 12 | koulamoutou
# Processing Record 12 of Set 12 | abu samrah
# Processing Record 13 of Set 12 | cooma
# Processing Record 14 of Set 12 | astana
# Processing Record 15 of Set 12 | sento se
# City not found. Skipping...
# Processing Record 16 of Set 12 | rocha
# Processing Record 17 of Set 12 | sistranda
# Processing Record 18 of Set 12 | areia branca
# Processing Record 19 of Set 12 | coquimbo
# Processing Record 20 of Set 12 | neiafu
# Processing Record 21 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 12 | ramgarh
# Processing Record 23 of Set 12 | pangkalanbuun
# Processing Record 24 of Set 12 | casablanca
# Processing Record 25 of Set 12 | alice springs
# Processing Record 26 of Set 12 | cangucu
# Processing Record 27 of Set 12 | kankan
# Processing Record 28 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 12 | waingapu
# Processing Record 30 of Set 12 | valley station
# Processing Record 31 of Set 12 | outjo
# Processing Record 32 of Set 12 | pekalongan
# Processing Record 33 of Set 12 | camopi
# Processing Record 34 of Set 12 | cochrane
# Processing Record 35 of Set 12 | aswan
# Processing Record 36 of Set 12 | jalu
# Processing Record 37 of Set 12 | sulangan
# Processing Record 38 of Set 12 | saint simons
# Processing Record 39 of Set 12 | davila
# Processing Record 40 of Set 12 | bengbu
# Processing Record 41 of Set 12 | rio grande
# Processing Record 42 of Set 12 | yumen
# Processing Record 43 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 12 | singaraja
# Processing Record 45 of Set 12 | saint george
# Processing Record 46 of Set 12 | pimentel
# Processing Record 47 of Set 12 | presidencia roque saenz pena
# Processing Record 48 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 12 | tobol
# Processing Record 0 of Set 13 | kyren
# Processing Record 1 of Set 13 | marquard
# Processing Record 2 of Set 13 | praia da vitoria
# Processing Record 3 of Set 13 | pemba
# Processing Record 4 of Set 13 | bembereke
# Processing Record 5 of Set 13 | baherden
# Processing Record 6 of Set 13 | port-cartier
# Processing Record 7 of Set 13 | waw
# Processing Record 8 of Set 13 | camacha
# Processing Record 9 of Set 13 | paamiut
# Processing Record 10 of Set 13 | yatou
# Processing Record 11 of Set 13 | neuquen
# Processing Record 12 of Set 13 | honiara
# Processing Record 13 of Set 13 | maputo
# Processing Record 14 of Set 13 | oktyabrskiy
# Processing Record 15 of Set 13 | utena
# Processing Record 16 of Set 13 | cruzilia
# Processing Record 17 of Set 13 | riyadh
# Processing Record 18 of Set 13 | olinda
# Processing Record 19 of Set 13 | shimoda
# Processing Record 20 of Set 13 | machali
# Processing Record 21 of Set 13 | luau
# Processing Record 22 of Set 13 | roma
# Processing Record 23 of Set 13 | jacareacanga
# Processing Record 24 of Set 13 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)


city_data_pd.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          vaini -21.20 -175.20     77.00        73          75        6.93
# 1         barrow  71.29 -156.79     32.00        95          90       10.29
# 2  potchefstroom -26.72   27.10     51.49        46           0        9.15
# 3        gigmoto  13.78  124.39     82.96        82          90        8.48
# 4      abu dhabi  24.47   54.37     87.80        52          66        4.70
#
#   Country        Date
# 0      TO  1590447781
# 1      US  1590447781
# 2      ZA  1590447781
# 3      PH  1590447712
# 4      AE  1590447606

# %%
# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
lng = city_data_pd["Lng"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# %%
# Export the City_Data into a csv
city_data_pd.to_csv('cities.csv', index_label="City_ID")

# %%
# Show Record Count
city_data_pd.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          vaini -21.20 -175.20     77.00        73          75        6.93
# 1         barrow  71.29 -156.79     32.00        95          90       10.29
# 2  potchefstroom -26.72   27.10     51.49        46           0        9.15
# 3        gigmoto  13.78  124.39     82.96        82          90        8.48
# 4      abu dhabi  24.47   54.37     87.80        52          66        4.70
#
#   Country        Date
# 0      TO  1590447781
# 1      US  1590447781
# 2      ZA  1590447781
# 3      PH  1590447712
# 4      AE  1590447606

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure


# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure


# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
